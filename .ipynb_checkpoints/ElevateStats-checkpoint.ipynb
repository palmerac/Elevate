# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %%
df = pd.read_csv('elevate_activities_export.2023.8.2-11.27.23.csv')
df.head()
# Out:
#                        Date  Type Moving Time  Distance (km)  \
# 0  2023-08-02T12:56:14.000Z   Run       37:55            5.1
# 1  2023-08-01T20:04:42.000Z  Ride    01:36:44           35.0
# 2  2023-07-31T18:54:55.000Z  Ride    01:14:54           24.8
# 3  2023-07-31T13:58:36.000Z   Run       53:18            7.0
# 4  2023-07-30T15:51:01.000Z   Run       29:48            4.0
#
#    Elevation Gain (m)  Avg Speed (kph) Avg Pace (/km)  Calories  \
# 0                   9              8.1          07:24       441
# 1                 130             21.7          02:46       828
# 2                 101             19.9          03:01       579
# 3                  15              7.9          07:34       584
# 4                   3              8.0          07:27       315
#
#   Grade Adj. Pace (/km) Best 20min Pace (/km)  ...  HRSS / h  \
# 0                 07:25                 07:20  ...        66
# 1                     -                 02:17  ...        57
# ...

# %%
df['Date'] = pd.to_datetime(df['Date']).dt.date
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 2
#       1 df['Date'] = pd.to_datetime(df['Date']).dt.date
# ----> 2 df['Moving Time'] = pd.to_datetime(df['Moving Time']).dt.date
#       3 for i, time_value in enumerate(df['Moving Time']):
#       4     time_parts = time_value.split(':')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# -> 1068         values = convert_listlike(arg._values, format)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...

# %%
dfRun = df[df['Type'] == 'Run']
dfRide = df[df['Type'] == 'Ride']

# dfRun.info()
# dfRide.info()

# %%
dfRun.describe()
# Out:
#        Distance (km)  Elevation Gain (m)  Avg Speed (kph)    Calories  \
# count       9.000000            9.000000         9.000000    9.000000
# mean        5.144444            9.222222         8.022222  411.444444
# std         1.322035            8.969083         0.405518  114.088903
# min         3.800000            3.000000         7.400000  289.000000
# 25%         4.100000            3.000000         7.800000  315.000000
# 50%         5.100000            4.000000         8.000000  399.000000
# 75%         5.400000           12.000000         8.300000  441.000000
# max         7.500000           30.000000         8.700000  598.000000
#
#        Avg HR (bpm)  Max HR (bpm)       Hrss   HRSS / h  Best 20min HR (bpm)  \
# count      9.000000      9.000000   9.000000   9.000000             9.000000
# mean     152.666667    166.777778  39.444444  62.777778           156.222222
# std        4.415880      7.870479   7.907451   6.591240             4.437842
# ...
